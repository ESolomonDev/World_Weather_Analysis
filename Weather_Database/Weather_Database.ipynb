# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #adding discription
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | port blair
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | te anau
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | isangel
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | noumea
# Processing Record 12 of Set 1 | moyale
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | spruce grove
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | vao
# Processing Record 17 of Set 1 | cayenne
# Processing Record 18 of Set 1 | coihaique
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | andros town
# Processing Record 21 of Set 1 | bathsheba
# Processing Record 22 of Set 1 | borogontsy
# Processing Record 23 of Set 1 | wittlich
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | faya
# Processing Record 29 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | goundam
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | marawi
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | olinda
# Processing Record 37 of Set 1 | loudeac
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | fallon
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | kaoma
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | bauchi
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | harwich
# Processing Record 47 of Set 1 | kondinskoye
# Processing Record 48 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 49 of Set 1 | pitimbu
# Processing Record 50 of Set 1 | makakilo city
# Processing Record 1 of Set 2 | gaoual
# Processing Record 2 of Set 2 | guerrero negro
# Processing Record 3 of Set 2 | batagay
# Processing Record 4 of Set 2 | saurimo
# Processing Record 5 of Set 2 | two rivers
# Processing Record 6 of Set 2 | platteville
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | kati
# Processing Record 9 of Set 2 | berlevag
# Processing Record 10 of Set 2 | port hardy
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | cardoso
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | santa isabel do rio negro
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | port lavaca
# Processing Record 18 of Set 2 | portland
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | cabo san lucas
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 2 | bodden town
# Processing Record 29 of Set 2 | tsumeb
# Processing Record 30 of Set 2 | alexandria
# Processing Record 31 of Set 2 | kahului
# Processing Record 32 of Set 2 | magadi
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | shetpe
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | burnie
# Processing Record 40 of Set 2 | santa maria del oro
# Processing Record 41 of Set 2 | saint-pierre
# Processing Record 42 of Set 2 | carlisle
# Processing Record 43 of Set 2 | vitim
# Processing Record 44 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | viseu
# Processing Record 47 of Set 2 | malanje
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | alice springs
# Processing Record 50 of Set 2 | kyra
# Processing Record 1 of Set 3 | gravdal
# Processing Record 2 of Set 3 | bilibino
# Processing Record 3 of Set 3 | vangaindrano
# Processing Record 4 of Set 3 | ucluelet
# Processing Record 5 of Set 3 | porosozero
# Processing Record 6 of Set 3 | flin flon
# Processing Record 7 of Set 3 | codajas
# Processing Record 8 of Set 3 | kaitangata
# Processing Record 9 of Set 3 | kununurra
# Processing Record 10 of Set 3 | atuona
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | dhidhdhoo
# Processing Record 13 of Set 3 | pimenta bueno
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | nabire
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | majene
# Processing Record 22 of Set 3 | stillwater
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | umkomaas
# Processing Record 26 of Set 3 | anadyr
# Processing Record 27 of Set 3 | quang ngai
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | port moresby
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | san felipe
# Processing Record 33 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 3 | fairbanks
# Processing Record 35 of Set 3 | shahreza
# Processing Record 36 of Set 3 | chapais
# Processing Record 37 of Set 3 | tobol
# Processing Record 38 of Set 3 | san fernando
# Processing Record 39 of Set 3 | geraldton
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | fort nelson
# Processing Record 42 of Set 3 | gamba
# Processing Record 43 of Set 3 | barroualie
# City not found. Skipping...
# Processing Record 44 of Set 3 | kandrian
# Processing Record 45 of Set 3 | miri
# Processing Record 46 of Set 3 | mitsamiouli
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | vieques
# Processing Record 50 of Set 3 | ullapool
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | sibolga
# Processing Record 3 of Set 4 | san policarpo
# Processing Record 4 of Set 4 | sept-iles
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | greytown
# Processing Record 8 of Set 4 | namatanai
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 4 | yuryevets
# Processing Record 12 of Set 4 | celestun
# Processing Record 13 of Set 4 | tateyama
# Processing Record 14 of Set 4 | russell
# Processing Record 15 of Set 4 | abbeyfeale
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 4 | yar-sale
# Processing Record 19 of Set 4 | houlton
# Processing Record 20 of Set 4 | rabo de peixe
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | saint-georges
# Processing Record 23 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 4 | rincon
# Processing Record 25 of Set 4 | zaqatala
# Processing Record 26 of Set 4 | agadez
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | suez
# Processing Record 29 of Set 4 | gat
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | tiznit
# Processing Record 33 of Set 4 | tonj
# Processing Record 34 of Set 4 | bilma
# Processing Record 35 of Set 4 | morondava
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | yellowknife
# Processing Record 38 of Set 4 | nikolskoye
# Processing Record 39 of Set 4 | dingle
# Processing Record 40 of Set 4 | tres arroyos
# Processing Record 41 of Set 4 | margate
# Processing Record 42 of Set 4 | capao da canoa
# Processing Record 43 of Set 4 | batagay-alyta
# Processing Record 44 of Set 4 | imeni poliny osipenko
# Processing Record 45 of Set 4 | winfield
# Processing Record 46 of Set 4 | walvis bay
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | altoona
# Processing Record 1 of Set 5 | kamaishi
# Processing Record 2 of Set 5 | kindu
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | inta
# Processing Record 6 of Set 5 | zajecar
# Processing Record 7 of Set 5 | okakarara
# Processing Record 8 of Set 5 | clyde river
# Processing Record 9 of Set 5 | khasan
# Processing Record 10 of Set 5 | lock haven
# Processing Record 11 of Set 5 | roma
# Processing Record 12 of Set 5 | saint-joseph
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | sorkjosen
# Processing Record 15 of Set 5 | narsaq
# Processing Record 16 of Set 5 | half moon bay
# Processing Record 17 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 5 | umm kaddadah
# Processing Record 19 of Set 5 | hervey bay
# Processing Record 20 of Set 5 | ayr
# Processing Record 21 of Set 5 | alyangula
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | sampit
# Processing Record 25 of Set 5 | atar
# Processing Record 26 of Set 5 | handwara
# City not found. Skipping...
# Processing Record 27 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 5 | artemovsk
# Processing Record 29 of Set 5 | muros
# Processing Record 30 of Set 5 | brejo
# Processing Record 31 of Set 5 | northam
# Processing Record 32 of Set 5 | port hedland
# Processing Record 33 of Set 5 | sri aman
# Processing Record 34 of Set 5 | soyo
# Processing Record 35 of Set 5 | morant bay
# Processing Record 36 of Set 5 | grand gaube
# Processing Record 37 of Set 5 | bac lieu
# Processing Record 38 of Set 5 | bredasdorp
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | aksu
# Processing Record 41 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 5 | ahome
# Processing Record 43 of Set 5 | zemio
# Processing Record 44 of Set 5 | ambovombe
# Processing Record 45 of Set 5 | sangar
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | chester
# Processing Record 48 of Set 5 | shaunavon
# Processing Record 49 of Set 5 | susuman
# Processing Record 50 of Set 5 | saint-philippe
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | vostok
# Processing Record 3 of Set 6 | cabra
# Processing Record 4 of Set 6 | chitral
# Processing Record 5 of Set 6 | conyers
# Processing Record 6 of Set 6 | itarema
# Processing Record 7 of Set 6 | haines junction
# Processing Record 8 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 6 | vestmannaeyjar
# Processing Record 10 of Set 6 | khandyga
# Processing Record 11 of Set 6 | aripuana
# Processing Record 12 of Set 6 | lithakia
# Processing Record 13 of Set 6 | waitati
# Processing Record 14 of Set 6 | san rafael del sur
# Processing Record 15 of Set 6 | kenai
# Processing Record 16 of Set 6 | ankazoabo
# Processing Record 17 of Set 6 | luanda
# Processing Record 18 of Set 6 | avera
# Processing Record 19 of Set 6 | channel-port aux basques
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | fortuna
# Processing Record 22 of Set 6 | nawa
# Processing Record 23 of Set 6 | antalaha
# Processing Record 24 of Set 6 | changde
# Processing Record 25 of Set 6 | belaya gora
# Processing Record 26 of Set 6 | yueyang
# Processing Record 27 of Set 6 | carutapera
# Processing Record 28 of Set 6 | tasiilaq
# Processing Record 29 of Set 6 | koboldo
# City not found. Skipping...
# Processing Record 30 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 6 | charters towers
# Processing Record 32 of Set 6 | cidreira
# Processing Record 33 of Set 6 | kesennuma
# City not found. Skipping...
# Processing Record 34 of Set 6 | udachnyy
# Processing Record 35 of Set 6 | matadi
# Processing Record 36 of Set 6 | krasnoselkup
# Processing Record 37 of Set 6 | baykit
# Processing Record 38 of Set 6 | hermosillo
# Processing Record 39 of Set 6 | igrim
# Processing Record 40 of Set 6 | aklavik
# Processing Record 41 of Set 6 | seymchan
# Processing Record 42 of Set 6 | yerofey pavlovich
# Processing Record 43 of Set 6 | gizo
# Processing Record 44 of Set 6 | severo-kurilsk
# Processing Record 45 of Set 6 | lalmohan
# Processing Record 46 of Set 6 | tutoia
# Processing Record 47 of Set 6 | yomou
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | marihatag
# Processing Record 50 of Set 6 | san quintin
# Processing Record 1 of Set 7 | zhezkazgan
# Processing Record 2 of Set 7 | arkhangelsk
# Processing Record 3 of Set 7 | praia da vitoria
# Processing Record 4 of Set 7 | worthing
# Processing Record 5 of Set 7 | cajamarca
# Processing Record 6 of Set 7 | brae
# Processing Record 7 of Set 7 | niteroi
# Processing Record 8 of Set 7 | trelew
# Processing Record 9 of Set 7 | shingu
# Processing Record 10 of Set 7 | riihimaki
# Processing Record 11 of Set 7 | honiara
# Processing Record 12 of Set 7 | iqaluit
# Processing Record 13 of Set 7 | mosquera
# Processing Record 14 of Set 7 | bubaque
# Processing Record 15 of Set 7 | norman wells
# Processing Record 16 of Set 7 | hasaki
# Processing Record 17 of Set 7 | komsomolskiy
# Processing Record 18 of Set 7 | vatava
# Processing Record 19 of Set 7 | lakselv
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 22 of Set 7 | kijang
# Processing Record 23 of Set 7 | mount isa
# Processing Record 24 of Set 7 | san juan de abajo
# Processing Record 25 of Set 7 | ponta do sol
# Processing Record 26 of Set 7 | camalu
# Processing Record 27 of Set 7 | guasdualito
# Processing Record 28 of Set 7 | qaqortoq
# Processing Record 29 of Set 7 | talanga
# Processing Record 30 of Set 7 | visby
# Processing Record 31 of Set 7 | gra liyia
# Processing Record 32 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 7 | urumqi
# Processing Record 34 of Set 7 | jumla
# Processing Record 35 of Set 7 | mayo
# Processing Record 36 of Set 7 | guaymas
# Processing Record 37 of Set 7 | lukovo
# Processing Record 38 of Set 7 | lata
# Processing Record 39 of Set 7 | guangyuan
# Processing Record 40 of Set 7 | auki
# Processing Record 41 of Set 7 | wanning
# Processing Record 42 of Set 7 | bakchar
# Processing Record 43 of Set 7 | broome
# Processing Record 44 of Set 7 | wuwei
# Processing Record 45 of Set 7 | senador guiomard
# Processing Record 46 of Set 7 | togur
# Processing Record 47 of Set 7 | akureyri
# Processing Record 48 of Set 7 | beringovskiy
# Processing Record 49 of Set 7 | constitucion
# Processing Record 50 of Set 7 | husavik
# Processing Record 1 of Set 8 | les cayes
# Processing Record 2 of Set 8 | hirara
# Processing Record 3 of Set 8 | ambon
# Processing Record 4 of Set 8 | jizan
# Processing Record 5 of Set 8 | santa rosa
# Processing Record 6 of Set 8 | namie
# Processing Record 7 of Set 8 | algiers
# Processing Record 8 of Set 8 | college
# Processing Record 9 of Set 8 | caiaponia
# Processing Record 10 of Set 8 | sar-e pul
# Processing Record 11 of Set 8 | olafsvik
# Processing Record 12 of Set 8 | jimma
# Processing Record 13 of Set 8 | nome
# Processing Record 14 of Set 8 | matagami
# Processing Record 15 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 8 | kismayo
# Processing Record 17 of Set 8 | bata
# Processing Record 18 of Set 8 | saldanha
# Processing Record 19 of Set 8 | kingseat
# Processing Record 20 of Set 8 | thinadhoo
# Processing Record 21 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 22 of Set 8 | zhigansk
# Processing Record 23 of Set 8 | upernavik
# Processing Record 24 of Set 8 | parkes
# Processing Record 25 of Set 8 | osypenko
# Processing Record 26 of Set 8 | sorong
# Processing Record 27 of Set 8 | nurota
# Processing Record 28 of Set 8 | chilliwack
# Processing Record 29 of Set 8 | jasper
# Processing Record 30 of Set 8 | emerald
# Processing Record 31 of Set 8 | derzhavinsk
# Processing Record 32 of Set 8 | mount gambier
# Processing Record 33 of Set 8 | zilair
# Processing Record 34 of Set 8 | cururupu
# Processing Record 35 of Set 8 | lagos
# Processing Record 36 of Set 8 | tariba
# Processing Record 37 of Set 8 | kasongo-lunda
# Processing Record 38 of Set 8 | nizhniy tsasuchey
# Processing Record 39 of Set 8 | varkaus
# Processing Record 40 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | sena madureira
# Processing Record 42 of Set 8 | zyryanka
# Processing Record 43 of Set 8 | tulsipur
# Processing Record 44 of Set 8 | japura
# Processing Record 45 of Set 8 | falmouth
# Processing Record 46 of Set 8 | saint-louis
# Processing Record 47 of Set 8 | ugoofaaru
# Processing Record 48 of Set 8 | jacqueville
# Processing Record 49 of Set 8 | isla vista
# Processing Record 50 of Set 8 | tolosa
# Processing Record 1 of Set 9 | bundaberg
# Processing Record 2 of Set 9 | christchurch
# Processing Record 3 of Set 9 | port lincoln
# Processing Record 4 of Set 9 | kazlu ruda
# Processing Record 5 of Set 9 | bowen
# Processing Record 6 of Set 9 | dire
# Processing Record 7 of Set 9 | semiluki
# Processing Record 8 of Set 9 | los llanos de aridane
# Processing Record 9 of Set 9 | barcelona
# Processing Record 10 of Set 9 | nizwa
# Processing Record 11 of Set 9 | biak
# Processing Record 12 of Set 9 | filotion
# Processing Record 13 of Set 9 | hermiston
# Processing Record 14 of Set 9 | hambantota
# Processing Record 15 of Set 9 | bakal
# Processing Record 16 of Set 9 | praia
# Processing Record 17 of Set 9 | ancud
# Processing Record 18 of Set 9 | richards bay
# Processing Record 19 of Set 9 | acarau
# Processing Record 20 of Set 9 | den helder
# Processing Record 21 of Set 9 | barentin
# Processing Record 22 of Set 9 | pemangkat
# Processing Record 23 of Set 9 | nanakuli
# Processing Record 24 of Set 9 | grindavik
# Processing Record 25 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 9 | oktyabrskoye
# Processing Record 27 of Set 9 | temirtau
# Processing Record 28 of Set 9 | tokur
# Processing Record 29 of Set 9 | canutama
# Processing Record 30 of Set 9 | sistranda
# Processing Record 31 of Set 9 | maues
# Processing Record 32 of Set 9 | finnsnes
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | puerto maldonado
# Processing Record 35 of Set 9 | alanganallur
# Processing Record 36 of Set 9 | krasnogorskiy
# Processing Record 37 of Set 9 | nyurba
# Processing Record 38 of Set 9 | poum
# Processing Record 39 of Set 9 | turayf
# Processing Record 40 of Set 9 | westport
# Processing Record 41 of Set 9 | fairview
# Processing Record 42 of Set 9 | maragogi
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | necochea
# Processing Record 45 of Set 9 | erzin
# Processing Record 46 of Set 9 | ayagoz
# Processing Record 47 of Set 9 | ahipara
# Processing Record 48 of Set 9 | nazareno
# Processing Record 49 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 9 | kutum
# Processing Record 1 of Set 10 | ambilobe
# Processing Record 2 of Set 10 | bellevue
# Processing Record 3 of Set 10 | provideniya
# Processing Record 4 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 10 | san patricio
# Processing Record 6 of Set 10 | wembley
# Processing Record 7 of Set 10 | pak phanang
# Processing Record 8 of Set 10 | bergama
# Processing Record 9 of Set 10 | tarnogskiy gorodok
# Processing Record 10 of Set 10 | rantepao
# Processing Record 11 of Set 10 | gisborne
# Processing Record 12 of Set 10 | astoria
# Processing Record 13 of Set 10 | rehoboth
# Processing Record 14 of Set 10 | hornbaek
# Processing Record 15 of Set 10 | canar
# Processing Record 16 of Set 10 | san cristobal
# Processing Record 17 of Set 10 | sibiti
# Processing Record 18 of Set 10 | basco
# Processing Record 19 of Set 10 | kawalu
# Processing Record 20 of Set 10 | pozo colorado
# Processing Record 21 of Set 10 | san ramon
# Processing Record 22 of Set 10 | puerto rondon
# Processing Record 23 of Set 10 | pingdingshan
# Processing Record 24 of Set 10 | natal
# Processing Record 25 of Set 10 | rodrigues alves
# Processing Record 26 of Set 10 | puerto del rosario
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | wanaka
# Processing Record 29 of Set 10 | yumen
# Processing Record 30 of Set 10 | aykhal
# Processing Record 31 of Set 10 | neuquen
# Processing Record 32 of Set 10 | pavlohrad
# Processing Record 33 of Set 10 | rio claro
# Processing Record 34 of Set 10 | oruro
# Processing Record 35 of Set 10 | airai
# Processing Record 36 of Set 10 | bambanglipuro
# Processing Record 37 of Set 10 | chumikan
# Processing Record 38 of Set 10 | samarai
# Processing Record 39 of Set 10 | mitu
# Processing Record 40 of Set 10 | semibratovo
# Processing Record 41 of Set 10 | voh
# Processing Record 42 of Set 10 | fort-shevchenko
# Processing Record 43 of Set 10 | lamar
# Processing Record 44 of Set 10 | gazanjyk
# Processing Record 45 of Set 10 | cockburn town
# Processing Record 46 of Set 10 | mogadishu
# Processing Record 47 of Set 10 | ixtapa
# Processing Record 48 of Set 10 | pareora
# Processing Record 49 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 50 of Set 10 | mao
# Processing Record 1 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 2 of Set 11 | oklahoma city
# Processing Record 3 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 4 of Set 11 | lubao
# Processing Record 5 of Set 11 | oil city
# Processing Record 6 of Set 11 | yumbe
# Processing Record 7 of Set 11 | synya
# Processing Record 8 of Set 11 | la romana
# Processing Record 9 of Set 11 | port arthur
# Processing Record 10 of Set 11 | juneau
# Processing Record 11 of Set 11 | tynda
# Processing Record 12 of Set 11 | palmer
# Processing Record 13 of Set 11 | buala
# Processing Record 14 of Set 11 | khatanga
# Processing Record 15 of Set 11 | bereznik
# Processing Record 16 of Set 11 | ures
# Processing Record 17 of Set 11 | terlizzi
# Processing Record 18 of Set 11 | gustrow
# Processing Record 19 of Set 11 | mehamn
# Processing Record 20 of Set 11 | canyon
# Processing Record 21 of Set 11 | nioro
# Processing Record 22 of Set 11 | beloha
# Processing Record 23 of Set 11 | nacimiento
# Processing Record 24 of Set 11 | araouane
# Processing Record 25 of Set 11 | hauge
# Processing Record 26 of Set 11 | wad madani
# Processing Record 27 of Set 11 | kulhudhuffushi
# Processing Record 28 of Set 11 | luganville
# Processing Record 29 of Set 11 | salalah
# Processing Record 30 of Set 11 | gilgil
# City not found. Skipping...
# Processing Record 31 of Set 11 | esil
# Processing Record 32 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 11 | tayshet
# Processing Record 34 of Set 11 | high prairie
# Processing Record 35 of Set 11 | tekirdag
# Processing Record 36 of Set 11 | skorping
# Processing Record 37 of Set 11 | saint anthony
# Processing Record 38 of Set 11 | killybegs
# Processing Record 39 of Set 11 | teacapan
# Processing Record 40 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 11 | changji
# Processing Record 42 of Set 11 | koutiala
# Processing Record 43 of Set 11 | muisne
# Processing Record 44 of Set 11 | kargasok
# Processing Record 45 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 11 | deputatskiy
# Processing Record 47 of Set 11 | collie
# Processing Record 48 of Set 11 | kavaratti
# Processing Record 49 of Set 11 | ballina
# Processing Record 50 of Set 11 | fillan
# Processing Record 1 of Set 12 | beyneu
# Processing Record 2 of Set 12 | mama
# Processing Record 3 of Set 12 | sao filipe
# Processing Record 4 of Set 12 | montague
# Processing Record 5 of Set 12 | inhambane
# Processing Record 6 of Set 12 | nouadhibou
# Processing Record 7 of Set 12 | sierra vista
# Processing Record 8 of Set 12 | biltine
# Processing Record 9 of Set 12 | saint george
# Processing Record 10 of Set 12 | namibe
# Processing Record 11 of Set 12 | maceio
# Processing Record 12 of Set 12 | vammala
# Processing Record 13 of Set 12 | san jose
# Processing Record 14 of Set 12 | camacha
# Processing Record 15 of Set 12 | parkersburg
# Processing Record 16 of Set 12 | susanville
# Processing Record 17 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 12 | lugovoy
# Processing Record 19 of Set 12 | marzuq
# Processing Record 20 of Set 12 | waingapu
# Processing Record 21 of Set 12 | poyarkovo
# Processing Record 22 of Set 12 | orsha
# Processing Record 23 of Set 12 | salym
# Processing Record 24 of Set 12 | hofn
# Processing Record 25 of Set 12 | tambun
# Processing Record 26 of Set 12 | friedeburg
# Processing Record 27 of Set 12 | oda
# Processing Record 28 of Set 12 | coahuayana
# Processing Record 29 of Set 12 | lavrentiya
# Processing Record 30 of Set 12 | dauphin
# Processing Record 31 of Set 12 | lorengau
# Processing Record 32 of Set 12 | bargur
# Processing Record 33 of Set 12 | pasni
# Processing Record 34 of Set 12 | camopi
# Processing Record 35 of Set 12 | acapulco
# Processing Record 36 of Set 12 | malinovoye ozero
# Processing Record 37 of Set 12 | ca mau
# Processing Record 38 of Set 12 | coruripe
# Processing Record 39 of Set 12 | pangkalanbuun
# Processing Record 40 of Set 12 | saint-augustin
# Processing Record 41 of Set 12 | xinzhou
# Processing Record 42 of Set 12 | atikokan
# Processing Record 43 of Set 12 | puerto plata
# Processing Record 44 of Set 12 | kaeo
# Processing Record 45 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 12 | kukushtan
# Processing Record 47 of Set 12 | antofagasta
# Processing Record 48 of Set 12 | dzaoudzi
# Processing Record 49 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 13 | makasar
# Processing Record 2 of Set 13 | juegang
# Processing Record 3 of Set 13 | laguna
# Processing Record 4 of Set 13 | tecuala
# Processing Record 5 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 13 | caruray
# Processing Record 7 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 13 | itupiranga
# Processing Record 9 of Set 13 | kirakira
# Processing Record 10 of Set 13 | dabakala
# Processing Record 11 of Set 13 | koungou
# Processing Record 12 of Set 13 | tual
# Processing Record 13 of Set 13 | port keats
# Processing Record 14 of Set 13 | trincomalee
# Processing Record 15 of Set 13 | ozernovskiy
# Processing Record 16 of Set 13 | muravlenko
# Processing Record 17 of Set 13 | san luis
# Processing Record 18 of Set 13 | tsiroanomandidy
# Processing Record 19 of Set 13 | zhanaozen
# Processing Record 20 of Set 13 | marathopolis
# City not found. Skipping...
# Processing Record 21 of Set 13 | sambava
# Processing Record 22 of Set 13 | yamnytsya
# Processing Record 23 of Set 13 | ciro marina
# Processing Record 24 of Set 13 | chadiza
# Processing Record 25 of Set 13 | green valley
# Processing Record 26 of Set 13 | yulara
# Processing Record 27 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 13 | katangli
# Processing Record 29 of Set 13 | sola
# Processing Record 30 of Set 13 | launceston
# Processing Record 31 of Set 13 | oranjemund
# Processing Record 32 of Set 13 | mareeba
# Processing Record 33 of Set 13 | hamilton
# Processing Record 34 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 13 | sawtell
# Processing Record 36 of Set 13 | severnyy
# Processing Record 37 of Set 13 | sakakah
# Processing Record 38 of Set 13 | ahuimanu
# Processing Record 39 of Set 13 | popondetta
# Processing Record 40 of Set 13 | broken hill
# Processing Record 41 of Set 13 | fethiye
# Processing Record 42 of Set 13 | carthage
# Processing Record 43 of Set 13 | pyapon
# Processing Record 44 of Set 13 | yuci
# Processing Record 45 of Set 13 | madera
# Processing Record 46 of Set 13 | sharjah
# Processing Record 47 of Set 13 | west bay
# Processing Record 48 of Set 13 | campos do jordao
# Processing Record 49 of Set 13 | malartic
# Processing Record 50 of Set 13 | innisfail
# Processing Record 1 of Set 14 | ravenna
# Processing Record 2 of Set 14 | harper
# Processing Record 3 of Set 14 | prince rupert
# Processing Record 4 of Set 14 | paratinga
# Processing Record 5 of Set 14 | ewa beach
# Processing Record 6 of Set 14 | nehe
# Processing Record 7 of Set 14 | sabang
# Processing Record 8 of Set 14 | hami
# Processing Record 9 of Set 14 | sanandaj
# Processing Record 10 of Set 14 | tilichiki
# Processing Record 11 of Set 14 | riyadh
# Processing Record 12 of Set 14 | luba
# Processing Record 13 of Set 14 | sorland
# Processing Record 14 of Set 14 | sobolevo
# Processing Record 15 of Set 14 | addis abeba
# Processing Record 16 of Set 14 | sur
# Processing Record 17 of Set 14 | nicoya
# Processing Record 18 of Set 14 | ust-kulom
# Processing Record 19 of Set 14 | ishim
# Processing Record 20 of Set 14 | gerardmer
# Processing Record 21 of Set 14 | phalaborwa
# Processing Record 22 of Set 14 | porto santo
# Processing Record 23 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 14 | abong mbang
# Processing Record 25 of Set 14 | botelhos
# Processing Record 26 of Set 14 | camacupa
# Processing Record 27 of Set 14 | rocky mountain house
# Processing Record 28 of Set 14 | kirensk
# Processing Record 29 of Set 14 | karratha
# Processing Record 30 of Set 14 | lianyuan
# Processing Record 31 of Set 14 | ketchikan
# Processing Record 32 of Set 14 | canico
# Processing Record 33 of Set 14 | mildura
# Processing Record 34 of Set 14 | ordzhonikidze
# Processing Record 35 of Set 14 | stonewall
# Processing Record 36 of Set 14 | linhares
# Processing Record 37 of Set 14 | sosnovo-ozerskoye
# Processing Record 38 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 14 | bilecik
# Processing Record 40 of Set 14 | dalvik
# Processing Record 41 of Set 14 | veraval
# Processing Record 42 of Set 14 | muyezerskiy
# Processing Record 43 of Set 14 | asau
# Processing Record 44 of Set 14 | bonavista
# Processing Record 45 of Set 14 | port-gentil
# Processing Record 46 of Set 14 | zhangye
# Processing Record 47 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 14 | kabompo
# Processing Record 49 of Set 14 | sulangan
# Processing Record 50 of Set 14 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 1 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 15 | srednekolymsk
# Processing Record 3 of Set 15 | ust-kuyga
# Processing Record 4 of Set 15 | behbahan
# Processing Record 5 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 6 of Set 15 | bandarbeyla
# Processing Record 7 of Set 15 | filadelfia
# Processing Record 8 of Set 15 | jalu
# Processing Record 9 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 15 | strezhevoy
# Processing Record 11 of Set 15 | uberaba
# Processing Record 12 of Set 15 | sinnamary
# Processing Record 13 of Set 15 | labuan
# Processing Record 14 of Set 15 | korla
# Processing Record 15 of Set 15 | mosna
# Processing Record 16 of Set 15 | sines
# Processing Record 17 of Set 15 | eureka
# Processing Record 18 of Set 15 | santa cruz
# Processing Record 19 of Set 15 | katima mulilo
# Processing Record 20 of Set 15 | taraz
# Processing Record 21 of Set 15 | nambucca heads
# Processing Record 22 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 15 | baghdad
# Processing Record 24 of Set 15 | kayerkan
# Processing Record 25 of Set 15 | chacabuco
# Processing Record 26 of Set 15 | meulaboh
# Processing Record 27 of Set 15 | gumdag
# Processing Record 28 of Set 15 | point fortin
# Processing Record 29 of Set 15 | rock sound
# Processing Record 30 of Set 15 | kutahya
# Processing Record 31 of Set 15 | omaruru
# Processing Record 32 of Set 15 | whyalla
# Processing Record 33 of Set 15 | akdepe
# Processing Record 34 of Set 15 | yuxia
# Processing Record 35 of Set 15 | hualmay
# Processing Record 36 of Set 15 | pavullo nel frignano
# Processing Record 37 of Set 15 | banikoara
# Processing Record 38 of Set 15 | presidencia roque saenz pena
# Processing Record 39 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  New Norfolk -42.7826  147.0587     56.70        54          90        2.62
# 1   Port Blair  11.6667   92.7500     80.64        69          40       16.11
# 2        Bluff -46.6000  168.3333     51.80        65          81       15.10
# 3      Te Anau -45.4167  167.7167     44.65        83          76        3.20
# 4  Tuktoyaktuk  69.4541 -133.0374    -25.60        68           0        8.05
# 5      Ushuaia -54.8000  -68.3000     51.42        57          75       40.29
# 6        Vaini -21.2000 -175.2000     78.96        94          20        5.75
# 7        Pisco -13.7000  -76.2167     72.01        68           0        5.75
# 8      Isangel -19.5500  169.2667     79.30        89          76        4.07
# 9      Mataura -46.1927  168.8643     51.48        90         100        3.27
#
#   Country                 Date      Description
# 0      AU  2022-02-12 14:43:17  overcast clouds
# 1      IN  2022-02-12 14:43:17             haze
# 2      NZ  2022-02-12 14:43:18    broken clouds
# 3      NZ  2022-02-12 14:43:18    broken clouds
# 4      CA  2022-02-12 14:43:18        clear sky
# 5      AR  2022-02-12 14:43:19    broken clouds
# 6      TO  2022-02-12 14:43:19       few clouds
# 7      PE  2022-02-12 14:43:19        clear sky
# 8      VU  2022-02-12 14:43:19    broken clouds
# 9      NZ  2022-02-12 14:43:20  overcast clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  New Norfolk      AU  2022-02-12 14:43:17 -42.7826  147.0587     56.70
# 1   Port Blair      IN  2022-02-12 14:43:17  11.6667   92.7500     80.64
# 2        Bluff      NZ  2022-02-12 14:43:18 -46.6000  168.3333     51.80
# 3      Te Anau      NZ  2022-02-12 14:43:18 -45.4167  167.7167     44.65
# 4  Tuktoyaktuk      CA  2022-02-12 14:43:18  69.4541 -133.0374    -25.60
# 5      Ushuaia      AR  2022-02-12 14:43:19 -54.8000  -68.3000     51.42
# 6        Vaini      TO  2022-02-12 14:43:19 -21.2000 -175.2000     78.96
# 7        Pisco      PE  2022-02-12 14:43:19 -13.7000  -76.2167     72.01
# 8      Isangel      VU  2022-02-12 14:43:19 -19.5500  169.2667     79.30
# 9      Mataura      NZ  2022-02-12 14:43:20 -46.1927  168.8643     51.48
#
#    Humidity  Cloudiness  Wind Speed      Description
# 0        54          90        2.62  overcast clouds
# 1        69          40       16.11             haze
# 2        65          81       15.10    broken clouds
# 3        83          76        3.20    broken clouds
# 4        68           0        8.05        clear sky
# 5        57          75       40.29    broken clouds
# 6        94          20        5.75       few clouds
# 7        68           0        5.75        clear sky
# 8        89          76        4.07    broken clouds
# 9        90         100        3.27  overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
